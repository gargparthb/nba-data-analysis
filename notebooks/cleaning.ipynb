# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### Raw Data
# The data was scraped from the season summary pages from [Basketball Reference](basketball-reference.com). It catalogues every team's advanced stats from the 1977 (The first merged ABA-NBA season) season to the 2021 season. It has missing values as well as some completely empty columns.

# %%
raw_data = pd.read_csv('../data/teams.csv', thousands=',')
raw_data.head()
# Out:
#    Unnamed: 0                     Team   Age   W   L  PW  PL   MOV   SOS  \
# 0           0  Portland Trail Blazers*  24.5  49  33  55  27  5.59 -0.20
# 1           1          Denver Nuggets*  27.3  50  32  54  28  5.22 -0.27
# 2           2      Philadelphia 76ers*  25.6  50  32  51  31  3.94 -0.16
# 3           3   Golden State Warriors*  25.8  46  36  49  33  3.22 -0.12
# 4           4      Los Angeles Lakers*  27.2  53  29  48  34  2.72 -0.08
#
#     SRS  ...   .1  eFG%.1  TOV%.1  DRB%  FT/FGA.1   .2  \
# 0  5.39  ...  NaN   0.460    17.2  69.3     0.255  NaN
# 1  4.95  ...  NaN   0.463    18.2  68.0     0.211  NaN
# 2  3.78  ...  NaN   0.451    16.7  66.0     0.197  NaN
# 3  3.10  ...  NaN   0.470    17.2  67.8     0.224  NaN
# 4  2.64  ...  NaN   0.452    15.6  66.1     0.194  NaN
#
#                                    Arena   Attend.  Attend./G  Year
# 0                      Memorial Coliseum       NaN        NaN  1977
# 1                 McNichols Sports Arena       NaN        NaN  1977
# 2                           The Spectrum       NaN        NaN  1977
# 3  Oakland-Alameda County Coliseum Arena       NaN        NaN  1977
# 4                              The Forum  501434.0        NaN  1977
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Data Cleaning
# Including only the columns with actual data gets rid of the completely null columns.

# %%
filtered = raw_data[['Team', 'W', 'L', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg', 'DRtg', 'NRtg', 'Pace',
'FTr', '3PAr', 'TS%', "eFG%", 'TOV%', 'ORB%', "FT/FGA", "Arena", "Attend.", "Attend./G", 'Year']]

filtered.head()
# Out:
#                       Team   W   L  PW  PL   MOV   SOS   SRS   ORtg  DRtg  \
# 0  Portland Trail Blazers*  49  33  55  27  5.59 -0.20  5.39  103.2  98.0
# 1          Denver Nuggets*  50  32  54  28  5.22 -0.27  4.95  100.7  96.1
# 2      Philadelphia 76ers*  50  32  51  31  3.94 -0.16  3.78  101.2  97.6
# 3   Golden State Warriors*  46  36  49  33  3.22 -0.12  3.10  102.4  99.5
# 4      Los Angeles Lakers*  53  29  48  34  2.72 -0.08  2.64  101.4  98.9
#
#    ...  3PAr    TS%   eFG%  TOV%  ORB%  FT/FGA  \
# 0  ...   NaN  0.530  0.481  16.9  33.4   0.254
# 1  ...   NaN  0.531  0.481  18.8  34.2   0.275
# 2  ...   NaN  0.530  0.480  18.3  34.6   0.275
# 3  ...   NaN  0.518  0.475  15.6  33.0   0.211
# 4  ...   NaN  0.515  0.478  15.3  31.0   0.188
#
#                                    Arena   Attend.  Attend./G  Year
# 0                      Memorial Coliseum       NaN        NaN  1977
# 1                 McNichols Sports Arena       NaN        NaN  1977
# 2                           The Spectrum       NaN        NaN  1977
# 3  Oakland-Alameda County Coliseum Arena       NaN        NaN  1977
# 4                              The Forum  501434.0        NaN  1977
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Missing Values
# The missing values are all located in the 3PAr column, which measures the proportion between 3-point and 2-point shot attempts (The 3-point shot was only introduced in 1979). So any missing values will default to 0. The other missing values are in the attendence columns.

# %%
filtered.isnull().sum()
# Out:
# Team           0
# W              0
# L              0
# PW             0
# PL             0
# MOV            0
# SOS            0
# SRS            0
# ORtg           0
# DRtg           0
# NRtg           0
# Pace           0
# FTr            0
# 3PAr          66
# TS%            0
# eFG%           0
# TOV%           0
# ORB%           0
# FT/FGA         0
# Arena          0
# Attend.       80
# Attend./G    496
# Year           0
# dtype: int64

# %%
filtered['3PAr'].fillna(0, inplace = True)
filtered.head()
# Out:
#                       Team   W   L  PW  PL   MOV   SOS   SRS   ORtg  DRtg  \
# 0  Portland Trail Blazers*  49  33  55  27  5.59 -0.20  5.39  103.2  98.0
# 1          Denver Nuggets*  50  32  54  28  5.22 -0.27  4.95  100.7  96.1
# 2      Philadelphia 76ers*  50  32  51  31  3.94 -0.16  3.78  101.2  97.6
# 3   Golden State Warriors*  46  36  49  33  3.22 -0.12  3.10  102.4  99.5
# 4      Los Angeles Lakers*  53  29  48  34  2.72 -0.08  2.64  101.4  98.9
#
#    ...  3PAr    TS%   eFG%  TOV%  ORB%  FT/FGA  \
# 0  ...   0.0  0.530  0.481  16.9  33.4   0.254
# 1  ...   0.0  0.531  0.481  18.8  34.2   0.275
# 2  ...   0.0  0.530  0.480  18.3  34.6   0.275
# 3  ...   0.0  0.518  0.475  15.6  33.0   0.211
# 4  ...   0.0  0.515  0.478  15.3  31.0   0.188
#
#                                    Arena   Attend.  Attend./G  Year
# 0                      Memorial Coliseum       NaN        NaN  1977
# 1                 McNichols Sports Arena       NaN        NaN  1977
# 2                           The Spectrum       NaN        NaN  1977
# 3  Oakland-Alameda County Coliseum Arena       NaN        NaN  1977
# 4                              The Forum  501434.0        NaN  1977
#
# [5 rows x 23 columns]

# %% [markdown]
# To clean the other columns, we can estimate that total attendence is approximately 40 times the attendence per game, which replicates uneven attendance on weekends and weekdays. Otherwise, we have to drop the rows that don't have either value.

# %%
dropped = filtered.dropna(subset=['Attend.', 'Attend./G'], how='all')

dropped['Attend.'] = dropped.apply(
  lambda row: 40 * row['Attend./G'] if pd.isnull(row['Attend.']) else row['Attend.'],
  axis = 1
)

dropped['Attend./G'] = dropped.apply(
  lambda row: row['Attend.'] / 40 if pd.isnull(row['Attend./G']) else row['Attend./G'],
  axis = 1
)

dropped.head()
# Out:
#                        Team   W   L  PW  PL   MOV   SOS   SRS   ORtg   DRtg  \
# 4       Los Angeles Lakers*  53  29  48  34  2.72 -0.08  2.64  101.4   98.9
# 16          Boston Celtics*  44  38  36  46 -1.98  0.08 -1.90   96.5   98.3
# 17         New Orleans Jazz  35  47  33  49 -2.82  0.13 -2.68   97.0   99.7
# 26      Los Angeles Lakers*  45  37  48  34  2.67 -0.08  2.59  103.3  100.8
# 39           Boston Celtics  32  50  36  46 -1.95  0.09 -1.86   99.1  100.9
# ...                     ...  ..  ..  ..  ..   ...   ...   ...    ...    ...
# 1195        New York Knicks  21  45  20  46 -6.45 -0.26 -6.72  106.5  113.0
# 1196      Charlotte Hornets  23  42  19  46 -6.75 -0.28 -7.03  106.3  113.3
# 1197          Atlanta Hawks  20  47  18  49 -7.97  0.27 -7.71  107.2  114.8
# 1198    Cleveland Cavaliers  19  46  18  47 -7.89  0.12 -7.77  107.5  115.4
# 1199  Golden State Warriors  15  50  16  49 -8.71  0.59 -8.12  105.2  113.8
#
#       ...   3PAr    TS%   eFG%  TOV%  ORB%  FT/FGA  \
# 4     ...  0.000  0.515  0.478  15.3  31.0   0.188
# 16    ...  0.000  0.491  0.445  16.1  31.1   0.212
# 17    ...  0.000  0.501  0.453  16.6  31.0   0.222
# 26    ...  0.000  0.526  0.487  15.3  30.4   0.205
# 39    ...  0.000  0.505  0.458  16.1  32.4   0.220
# ...   ...    ...    ...    ...   ...   ...     ...
# 1195  ...  0.318  0.531  0.501  12.6  25.8   0.182
# 1196  ...  0.399  0.539  0.504  13.3  23.9   0.188
# 1197  ...  0.398  0.554  0.515  13.8  21.6   0.204
# 1198  ...  0.362  0.553  0.522  14.6  24.6   0.172
# 1199  ...  0.355  0.540  0.497  13.2  21.5   0.212
#
#                            Arena   Attend.  Attend./G  Year
# 4                      The Forum  501434.0  12535.850  1977
# 16                 Boston Garden  517391.0  12934.775  1977
# 17           Louisiana Superdome  441320.0  11033.000  1977
# 26                     The Forum  534017.0  13350.425  1978
# 39                 Boston Garden  437937.0  10948.425  1978
# ...                          ...       ...        ...   ...
# 1195  Madison Square Garden (IV)  620789.0  18812.000  2020
# 1196             Spectrum Center  478591.0  15428.000  2020
# 1197            State Farm Arena  545453.0  16043.000  2020
# 1198         Quicken Loans Arena  643008.0  17861.000  2020
# 1199                Chase Center  614176.0  18064.000  2020
#
# [1133 rows x 23 columns]

# %% [markdown]
# #### Finalizing the Dataset
# The source site of the data put a * on an team that made the postseason, since this serves no real purpose here, it is easy to remove them.

# %%
final = dropped.replace('\*','',regex=True).reset_index(drop=True)
final.head()
final.to_csv('../data/teams_processed.csv')

# %% [markdown]
# ### Evaluation of Data Cleaning
# By comparing the size of the first and final dataframes, we can get a good idea of how much data was wasted versus how much data was viable.

# %%
print("Shape of raw data: ", raw_data.shape)
print("Shape of cleaned data: ", final.shape, '\n')
print(len(final.index) - len(raw_data.index))
# Out:
# Shape of raw data:  (1200, 32)
# Shape of cleaned data:  (1133, 23)
